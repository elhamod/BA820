# %% [markdown]
# <a href="https://colab.research.google.com/github/elhamod/BA820/blob/main/Hands-on/02-hierarchical-clustering/Hierarchical_Clustering_California_Housing_Draft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this notebook, we will try to do clustering analysis of California housing market. We would like to find some trends in the housing market there.

# %% [markdown]
# ## Load the data

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/elhamod/BA820/main/Hands-on/02-hierarchical-clustering/Kaggle_housing.csv"
#https://www.kaggle.com/datasets/camnugent/california-housing-prices

df = pd.read_csv(url) # if you you are only interested in certain attributes: usecols = [...])

df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %% [markdown]
# ## Things to try:
#
#
#
# 1.   What could we have done about categorical data?
# 2.   Is there a way to make data more explainable? How does that affect results?
# 2.   What if we want to give more importance to a certain attribute?
# 3.   Maybe it is too much to ask to cluster based on all these attributes. Is there a chance to drop some of them? Which would you drop?
