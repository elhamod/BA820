# %% [markdown]
# <a href="https://colab.research.google.com/github/elhamod/BA820/blob/main/Hands-on/03-dimensionality-reduction/Diceroll.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Let's create data coming from a boardgame player rolling two dice, adding them up, and then making a move based on the result.

# %%
import numpy as np
import seaborn as sns
import plotly.express as px
from sklearn.decomposition import PCA
import pandas as pd

# %%
# Step 1: Create dice roll variables
X = np.random.randint(1, 7, 1000)
Y = np.random.randint(1, 7, 1000)
Z = X+Y

df = pd.DataFrame({'first die': X, 'second die': Y, 'result': Z})

# %% [markdown]
# Standardize the attributes.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
scaler = StandardScaler()
df = pd.DataFrame(scaler.fit_transform(df), columns = df.columns)

df
# Out:
#      first die  second die    result
# 0    -0.300004   -0.858267 -0.796901
# 1     0.274716    0.302337  0.397853
# 2     1.424158    0.882639  1.592608
# 3    -0.300004    1.462941  0.796105
# 4    -0.874725    0.302337 -0.398650
# ..         ...         ...       ...
# 995  -1.449445   -0.858267 -1.593405
# 996  -0.300004    1.462941  0.796105
# 997   1.424158   -0.858267  0.397853
# 998  -0.874725    1.462941  0.397853
# 999   0.274716   -1.438569 -0.796901
#
# [1000 rows x 3 columns]

# %% [markdown]
# Plot

# %%
fig = px.scatter_3d(df, x='first die', y='second die', z='result', title='3D Scatter plot of Dice Rolls')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Can we do dimensionality reduction without losing any information?

# %%
# Step 4: Perform PCA
pca = PCA()
df_pca = pca.fit_transform(df)

# %%
# Step 5: Scree plot using Seaborn
fig = sns.barplot(x=np.arange(1, pca.n_components_ + 1), y=pca.explained_variance_ratio_)

print(pca.explained_variance_ratio_)
# Out:
# [6.83782044e-01 3.16217956e-01 1.01809568e-31]
